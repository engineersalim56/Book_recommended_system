# %%
# Importing the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Loading the dataset
Bd = pd.read_csv('Books.csv')
Rd = pd.read_csv('Ratings.csv')
Ur = pd.read_csv('Users.csv')

# # Printing the shapes of the datasets
print(Bd.shape)
print(Rd.shape)
print(Ur.shape)
# Out:
# <ipython-input-21-c8df545ea3b2>:2: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   Bd = pd.read_csv('Books.csv')
# (271360, 8)
# (1149780, 3)
# (278858, 3)

# %%
Bd
# Out:
#               ISBN                                         Book-Title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271355  0440400988                         There's a Bat in Bunk Five
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271358  0192126040                        Republic (World's Classics)
# 271359  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                  Book-Author Year-Of-Publication  \
# 0         Mark P. O. Morford                2002
# 1       Richard Bruce Wright                2001
# 2               Carlo D'Este                1991
# 3           Gina Bari Kolata                1999
# 4            E. J. W. Barber                1999
# ...                      ...                 ...
# 271355        Paula Danziger                1988
# 271356            Teri Sloat                1991
# 271357      Christine Wicker                2004
# 271358                 Plato                1996
# 271359   Christopher  Biffle                2000
#
#                                                Publisher  \
# 0                                Oxford University Press
# 1                                  HarperFlamingo Canada
# 2                                        HarperPerennial
# 3                                   Farrar Straus Giroux
# 4                             W. W. Norton &amp; Company
# ...                                                  ...
# 271355                   Random House Childrens Pub (Mm)
# 271356                                      Dutton Books
# 271357                                HarperSanFrancisco
# 271358                           Oxford University Press
# 271359  McGraw-Hill Humanities/Social Sciences/Languages
#
#                                               Image-URL-S  \
# 0       http://images.amazon.com/images/P/0195153448.0...
# 1       http://images.amazon.com/images/P/0002005018.0...
# 2       http://images.amazon.com/images/P/0060973129.0...
# 3       http://images.amazon.com/images/P/0374157065.0...
# 4       http://images.amazon.com/images/P/0393045218.0...
# ...                                                   ...
# 271355  http://images.amazon.com/images/P/0440400988.0...
# 271356  http://images.amazon.com/images/P/0525447644.0...
# 271357  http://images.amazon.com/images/P/006008667X.0...
# 271358  http://images.amazon.com/images/P/0192126040.0...
# 271359  http://images.amazon.com/images/P/0767409752.0...
#
#                                               Image-URL-M  \
# 0       http://images.amazon.com/images/P/0195153448.0...
# 1       http://images.amazon.com/images/P/0002005018.0...
# 2       http://images.amazon.com/images/P/0060973129.0...
# 3       http://images.amazon.com/images/P/0374157065.0...
# 4       http://images.amazon.com/images/P/0393045218.0...
# ...                                                   ...
# 271355  http://images.amazon.com/images/P/0440400988.0...
# 271356  http://images.amazon.com/images/P/0525447644.0...
# 271357  http://images.amazon.com/images/P/006008667X.0...
# 271358  http://images.amazon.com/images/P/0192126040.0...
# 271359  http://images.amazon.com/images/P/0767409752.0...
#
#                                               Image-URL-L
# 0       http://images.amazon.com/images/P/0195153448.0...
# 1       http://images.amazon.com/images/P/0002005018.0...
# 2       http://images.amazon.com/images/P/0060973129.0...
# 3       http://images.amazon.com/images/P/0374157065.0...
# 4       http://images.amazon.com/images/P/0393045218.0...
# ...                                                   ...
# 271355  http://images.amazon.com/images/P/0440400988.0...
# 271356  http://images.amazon.com/images/P/0525447644.0...
# 271357  http://images.amazon.com/images/P/006008667X.0...
# 271358  http://images.amazon.com/images/P/0192126040.0...
# 271359  http://images.amazon.com/images/P/0767409752.0...
#
# [271360 rows x 8 columns]

# %%
Rd
# Out:
#          User-ID         ISBN  Book-Rating
# 0         276725   034545104X            0
# 1         276726   0155061224            5
# 2         276727   0446520802            0
# 3         276729   052165615X            3
# 4         276729   0521795028            6
# ...          ...          ...          ...
# 1149775   276704   1563526298            9
# 1149776   276706   0679447156            0
# 1149777   276709   0515107662           10
# 1149778   276721   0590442449           10
# 1149779   276723  05162443314            8
#
# [1149780 rows x 3 columns]

# %%
Ur
# Out:
#         User-ID                            Location   Age
# 0             1                  nyc, new york, usa   NaN
# 1             2           stockton, california, usa  18.0
# 2             3     moscow, yukon territory, russia   NaN
# 3             4           porto, v.n.gaia, portugal  17.0
# 4             5  farnborough, hants, united kingdom   NaN
# ...         ...                                 ...   ...
# 278853   278854               portland, oregon, usa   NaN
# 278854   278855  tacoma, washington, united kingdom  50.0
# 278855   278856           brampton, ontario, canada   NaN
# 278856   278857           knoxville, tennessee, usa   NaN
# 278857   278858                dublin, n/a, ireland   NaN
#
# [278858 rows x 3 columns]

# %%
# Checking for missing values in Rd and Ur
print("Missing values in Ratings dataset:")
print(Rd.isnull().sum())

print("\nMissing values in Users dataset:")
print(Ur.isnull().sum())
# Out:
# Missing values in Ratings dataset:
# User-ID        0
# ISBN           0
# Book-Rating    0
# dtype: int64
#
# Missing values in Users dataset:
# User-ID          0
# Location         0
# Age         110762
# dtype: int64

# %%
# Checking for duplicated entries in Bd, Ur, and Rd
print("Duplicated entries in Books dataset:")
print(Bd.duplicated())

print("\nDuplicated entries in Users dataset:")
print(Ur.duplicated())

print("\nDuplicated entries in Ratings dataset:")
print(Rd.duplicated())
# Out:
# Duplicated entries in Books dataset:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 271355    False
# 271356    False
# 271357    False
# 271358    False
# 271359    False
# Length: 271360, dtype: bool
#
# Duplicated entries in Users dataset:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 278853    False
# 278854    False
# 278855    False
# 278856    False
# 278857    False
# Length: 278858, dtype: bool
#
# Duplicated entries in Ratings dataset:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 1149775    False
# 1149776    False
# 1149777    False
# 1149778    False
# 1149779    False
# Length: 1149780, dtype: bool

# %%
# Merging Rd and Bd datasets
new_df = Rd.merge(Bd)
new_df
# Out:
#          User-ID        ISBN  Book-Rating  \
# 0         276725  034545104X            0
# 1         276726  0155061224            5
# 2         276727  0446520802            0
# 3         276729  052165615X            3
# 4         276729  0521795028            6
# ...          ...         ...          ...
# 1031131   276704  0876044011            0
# 1031132   276704  1563526298            9
# 1031133   276706  0679447156            0
# 1031134   276709  0515107662           10
# 1031135   276721  0590442449           10
#
#                                                 Book-Title        Book-Author  \
# 0                                     Flesh Tones: A Novel         M. J. Rose
# 1                                         Rites of Passage         Judith Rae
# 2                                             The Notebook    Nicholas Sparks
# 3                                           Help!: Level 1      Philip Prowse
# 4        The Amsterdam Connection : Level 4 (Cambridge ...        Sue Leather
# ...                                                    ...                ...
# 1031131  Edgar Cayce on the Akashic Records: The Book o...  Kevin J. Todeschi
# 1031132  Get Clark Smart : The Ultimate Guide for the S...       Clark Howard
# 1031133  Eight Weeks to Optimum Health: A Proven Progra...        Andrew Weil
# 1031134   The Sherbrooke Bride (Bride Trilogy (Paperback))  Catherine Coulter
# 1031135                                  Fourth Grade Rats     Jerry Spinelli
#
#         Year-Of-Publication  \
# 0                      2002
# 1                      2001
# 2                      1996
# 3                      1999
# 4                      2001
# ...                     ...
# 1031131                1998
# 1031132                2000
# 1031133                1997
# 1031134                1996
# 1031135                1996
#
#                                                  Publisher  \
# 0                                         Ballantine Books
# 1                                                   Heinle
# 2                                             Warner Books
# 3                               Cambridge University Press
# 4                               Cambridge University Press
# ...                                                    ...
# 1031131  A.R.E. Press (Association of Research &amp; Enlig
# 1031132                                   Longstreet Press
# 1031133                                    Alfred A. Knopf
# 1031134                                         Jove Books
# 1031135                                         Scholastic
#
#                                                Image-URL-S  \
# 0        http://images.amazon.com/images/P/034545104X.0...
# 1        http://images.amazon.com/images/P/0155061224.0...
# 2        http://images.amazon.com/images/P/0446520802.0...
# 3        http://images.amazon.com/images/P/052165615X.0...
# 4        http://images.amazon.com/images/P/0521795028.0...
# ...                                                    ...
# 1031131  http://images.amazon.com/images/P/0876044011.0...
# 1031132  http://images.amazon.com/images/P/1563526298.0...
# 1031133  http://images.amazon.com/images/P/0679447156.0...
# 1031134  http://images.amazon.com/images/P/0515107662.0...
# 1031135  http://images.amazon.com/images/P/0590442449.0...
#
#                                                Image-URL-M  \
# 0        http://images.amazon.com/images/P/034545104X.0...
# 1        http://images.amazon.com/images/P/0155061224.0...
# 2        http://images.amazon.com/images/P/0446520802.0...
# 3        http://images.amazon.com/images/P/052165615X.0...
# 4        http://images.amazon.com/images/P/0521795028.0...
# ...                                                    ...
# 1031131  http://images.amazon.com/images/P/0876044011.0...
# 1031132  http://images.amazon.com/images/P/1563526298.0...
# 1031133  http://images.amazon.com/images/P/0679447156.0...
# 1031134  http://images.amazon.com/images/P/0515107662.0...
# 1031135  http://images.amazon.com/images/P/0590442449.0...
#
#                                                Image-URL-L
# 0        http://images.amazon.com/images/P/034545104X.0...
# 1        http://images.amazon.com/images/P/0155061224.0...
# 2        http://images.amazon.com/images/P/0446520802.0...
# 3        http://images.amazon.com/images/P/052165615X.0...
# 4        http://images.amazon.com/images/P/0521795028.0...
# ...                                                    ...
# 1031131  http://images.amazon.com/images/P/0876044011.0...
# 1031132  http://images.amazon.com/images/P/1563526298.0...
# 1031133  http://images.amazon.com/images/P/0679447156.0...
# 1031134  http://images.amazon.com/images/P/0515107662.0...
# 1031135  http://images.amazon.com/images/P/0590442449.0...
#
# [1031136 rows x 10 columns]

# %%
# Merging Rd and Bd datasets based on ISBN
rating_with_name = Rd.merge(Bd, on="ISBN")
rating_with_name
# Out:
#          User-ID        ISBN  Book-Rating  \
# 0         276725  034545104X            0
# 1         276726  0155061224            5
# 2         276727  0446520802            0
# 3         276729  052165615X            3
# 4         276729  0521795028            6
# ...          ...         ...          ...
# 1031131   276704  0876044011            0
# 1031132   276704  1563526298            9
# 1031133   276706  0679447156            0
# 1031134   276709  0515107662           10
# 1031135   276721  0590442449           10
#
#                                                 Book-Title        Book-Author  \
# 0                                     Flesh Tones: A Novel         M. J. Rose
# 1                                         Rites of Passage         Judith Rae
# 2                                             The Notebook    Nicholas Sparks
# 3                                           Help!: Level 1      Philip Prowse
# 4        The Amsterdam Connection : Level 4 (Cambridge ...        Sue Leather
# ...                                                    ...                ...
# 1031131  Edgar Cayce on the Akashic Records: The Book o...  Kevin J. Todeschi
# 1031132  Get Clark Smart : The Ultimate Guide for the S...       Clark Howard
# 1031133  Eight Weeks to Optimum Health: A Proven Progra...        Andrew Weil
# 1031134   The Sherbrooke Bride (Bride Trilogy (Paperback))  Catherine Coulter
# 1031135                                  Fourth Grade Rats     Jerry Spinelli
#
#         Year-Of-Publication  \
# 0                      2002
# 1                      2001
# 2                      1996
# 3                      1999
# 4                      2001
# ...                     ...
# 1031131                1998
# 1031132                2000
# 1031133                1997
# 1031134                1996
# 1031135                1996
#
#                                                  Publisher  \
# 0                                         Ballantine Books
# 1                                                   Heinle
# 2                                             Warner Books
# 3                               Cambridge University Press
# 4                               Cambridge University Press
# ...                                                    ...
# 1031131  A.R.E. Press (Association of Research &amp; Enlig
# 1031132                                   Longstreet Press
# 1031133                                    Alfred A. Knopf
# 1031134                                         Jove Books
# 1031135                                         Scholastic
#
#                                                Image-URL-S  \
# 0        http://images.amazon.com/images/P/034545104X.0...
# 1        http://images.amazon.com/images/P/0155061224.0...
# 2        http://images.amazon.com/images/P/0446520802.0...
# 3        http://images.amazon.com/images/P/052165615X.0...
# 4        http://images.amazon.com/images/P/0521795028.0...
# ...                                                    ...
# 1031131  http://images.amazon.com/images/P/0876044011.0...
# 1031132  http://images.amazon.com/images/P/1563526298.0...
# 1031133  http://images.amazon.com/images/P/0679447156.0...
# 1031134  http://images.amazon.com/images/P/0515107662.0...
# 1031135  http://images.amazon.com/images/P/0590442449.0...
#
#                                                Image-URL-M  \
# 0        http://images.amazon.com/images/P/034545104X.0...
# 1        http://images.amazon.com/images/P/0155061224.0...
# 2        http://images.amazon.com/images/P/0446520802.0...
# 3        http://images.amazon.com/images/P/052165615X.0...
# 4        http://images.amazon.com/images/P/0521795028.0...
# ...                                                    ...
# 1031131  http://images.amazon.com/images/P/0876044011.0...
# 1031132  http://images.amazon.com/images/P/1563526298.0...
# 1031133  http://images.amazon.com/images/P/0679447156.0...
# 1031134  http://images.amazon.com/images/P/0515107662.0...
# 1031135  http://images.amazon.com/images/P/0590442449.0...
#
#                                                Image-URL-L
# 0        http://images.amazon.com/images/P/034545104X.0...
# 1        http://images.amazon.com/images/P/0155061224.0...
# 2        http://images.amazon.com/images/P/0446520802.0...
# 3        http://images.amazon.com/images/P/052165615X.0...
# 4        http://images.amazon.com/images/P/0521795028.0...
# ...                                                    ...
# 1031131  http://images.amazon.com/images/P/0876044011.0...
# 1031132  http://images.amazon.com/images/P/1563526298.0...
# 1031133  http://images.amazon.com/images/P/0679447156.0...
# 1031134  http://images.amazon.com/images/P/0515107662.0...
# 1031135  http://images.amazon.com/images/P/0590442449.0...
#
# [1031136 rows x 10 columns]

# %%
rating_with_name['Book-Rating'] = pd.to_numeric(rating_with_name['Book-Rating'], errors='coerce')
rating_with_name['Book-Rating'].fillna(rating_with_name['Book-Rating'].mean(), inplace=True)
avg_rating_df = rating_with_name.groupby("Book-Title")['Book-Rating'].mean().reset_index()
avg_rating_df.rename(columns={'Book-Rating': 'average-ratings'}, inplace=True)
avg_rating_df
# Out:
# <ipython-input-44-c9fe14166426>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   rating_with_name['Book-Rating'].fillna(rating_with_name['Book-Rating'].mean(), inplace=True)
#                                                Book-Title  average-ratings
# 0        A Light in the Storm: The Civil War Diary of ...         2.250000
# 1                                   Always Have Popsicles         0.000000
# 2                    Apple Magic (The Collector's series)         0.000000
# 3        Ask Lily (Young Women of Faith: Lily Series, ...         8.000000
# 4        Beyond IBM: Leadership Marketing and Finance ...         0.000000
# ...                                                   ...              ...
# 241066                                      Ã?Â?lpiraten.         0.000000
# 241067                     Ã?Â?rger mit Produkt X. Roman.         5.250000
# 241068                                Ã?Â?sterlich leben.         7.000000
# 241069                              Ã?Â?stlich der Berge.         2.666667
# 241070                                  Ã?Â?thique en toc         4.000000
#
# [241071 rows x 2 columns]

# %%
# Merging the number of ratings and average ratings DataFrames
popular_df = num_rating_df.merge(avg_rating_df, on="Book-Title")
popular_df
# Out:
#                                                Book-Title  number-ratings  \
# 0        A Light in the Storm: The Civil War Diary of ...               4
# 1                                   Always Have Popsicles               1
# 2                    Apple Magic (The Collector's series)               1
# 3        Ask Lily (Young Women of Faith: Lily Series, ...               1
# 4        Beyond IBM: Leadership Marketing and Finance ...               1
# ...                                                   ...             ...
# 241066                                      Ã?Â?lpiraten.               2
# 241067                     Ã?Â?rger mit Produkt X. Roman.               4
# 241068                                Ã?Â?sterlich leben.               1
# 241069                              Ã?Â?stlich der Berge.               3
# 241070                                  Ã?Â?thique en toc               2
#
#         average-ratings
# 0              2.250000
# 1              0.000000
# 2              0.000000
# 3              8.000000
# 4              0.000000
# ...                 ...
# 241066         0.000000
# 241067         5.250000
# 241068         7.000000
# 241069         2.666667
# 241070         4.000000
#
# [241071 rows x 3 columns]

# %%
# Assuming 'number-ratings' is a column in the DataFrame 'popular_df'
filtered_popular_df = popular_df[popular_df["number-ratings"] >= 200]
filtered_popular_df
# Out:
#                                                Book-Title  number-ratings  \
# 764                                                  1984             284
# 818                                   1st to Die: A Novel             509
# 1048                                           2nd Chance             356
# 1760                                   A Bend in the Road             346
# 2120                                       A Case of Need             236
# ...                                                   ...             ...
# 234951                                        Wild Animus            2502
# 236334                                      Wish You Well             234
# 236724                                    Without Remorse             203
# 240413  Zen and the Art of Motorcycle Maintenance: An ...             210
# 240860                                \O\" Is for Outlaw"             269
#
#         average-ratings
# 764            4.454225
# 818            3.575639
# 1048           3.269663
# 1760           3.364162
# 2120           2.423729
# ...                 ...
# 234951         1.019584
# 236334         3.012821
# 236724         2.881773
# 240413         3.147619
# 240860         2.988848
#
# [297 rows x 3 columns]

# %%
# Assuming 'rating' is a column in the DataFrame 'filtered_popular_df'
sorted_filtered_popular_df = filtered_popular_df.sort_values("average-ratings",ascending=False)

# %%
sorted_filtered_popular_df
# Out:
#                                                Book-Title  number-ratings  \
# 80434   Harry Potter and the Prisoner of Azkaban (Book 3)             428
# 80422        Harry Potter and the Goblet of Fire (Book 4)             387
# 80441      Harry Potter and the Sorcerer's Stone (Book 1)             278
# 80426   Harry Potter and the Order of the Phoenix (Boo...             347
# 60582       Ender's Game (Ender Wiggins Saga (Paperback))             249
# ...                                                   ...             ...
# 27600                                   Breathing Lessons             239
# 94382                                        Isle of Dogs             288
# 162153                           Slow Waltz in Cedar Bend             248
# 163913  Songs in Ordinary Time (Oprah's Book Club (Pap...             232
# 234951                                        Wild Animus            2502
#
#         average-ratings
# 80434          5.852804
# 80422          5.824289
# 80441          5.737410
# 80426          5.501441
# 60582          5.409639
# ...                 ...
# 27600          2.117155
# 94382          2.000000
# 162153         1.895161
# 163913         1.857759
# 234951         1.019584
#
# [297 rows x 3 columns]

# %%
popular_new_df=sorted_filtered_popular_df.merge(Bd,on="Book-Title")
popular_new_df
# Out:
#                                              Book-Title  number-ratings  \
# 0     Harry Potter and the Prisoner of Azkaban (Book 3)             428
# 1     Harry Potter and the Prisoner of Azkaban (Book 3)             428
# 2     Harry Potter and the Prisoner of Azkaban (Book 3)             428
# 3          Harry Potter and the Goblet of Fire (Book 4)             387
# 4          Harry Potter and the Goblet of Fire (Book 4)             387
# ...                                                 ...             ...
# 1127                           Slow Waltz in Cedar Bend             248
# 1128                           Slow Waltz in Cedar Bend             248
# 1129                           Slow Waltz in Cedar Bend             248
# 1130  Songs in Ordinary Time (Oprah's Book Club (Pap...             232
# 1131                                        Wild Animus            2502
#
#       average-ratings        ISBN          Book-Author Year-Of-Publication  \
# 0            5.852804  0439136350        J. K. Rowling                1999
# 1            5.852804  0439136369        J. K. Rowling                2001
# 2            5.852804  0786222743        J. K. Rowling                2000
# 3            5.824289  0439139597        J. K. Rowling                2000
# 4            5.824289  0439139600        J. K. Rowling                2002
# ...               ...         ...                  ...                 ...
# 1127         1.895161  0446516538  Robert James Waller                1993
# 1128         1.895161  074932032X  Robert James Waller                1995
# 1129         1.895161  0749317647  Robert James Waller                1995
# 1130         1.857759  0140244824  Mary McGarry Morris                1996
# 1131         1.019584  0971880107         Rich Shapero                2004
#
#                   Publisher  \
# 0                Scholastic
# 1                Scholastic
# 2           Thorndike Press
# 3                Scholastic
# 4     Scholastic Paperbacks
# ...                     ...
# 1127           Warner Books
# 1128               Mandarin
# 1129               Mandarin
# 1130          Penguin Books
# 1131                Too Far
#
#                                             Image-URL-S  \
# 0     http://images.amazon.com/images/P/0439136350.0...
# 1     http://images.amazon.com/images/P/0439136369.0...
# 2     http://images.amazon.com/images/P/0786222743.0...
# 3     http://images.amazon.com/images/P/0439139597.0...
# 4     http://images.amazon.com/images/P/0439139600.0...
# ...                                                 ...
# 1127  http://images.amazon.com/images/P/0446516538.0...
# 1128  http://images.amazon.com/images/P/074932032X.0...
# 1129  http://images.amazon.com/images/P/0749317647.0...
# 1130  http://images.amazon.com/images/P/0140244824.0...
# 1131  http://images.amazon.com/images/P/0971880107.0...
#
#                                             Image-URL-M  \
# 0     http://images.amazon.com/images/P/0439136350.0...
# 1     http://images.amazon.com/images/P/0439136369.0...
# 2     http://images.amazon.com/images/P/0786222743.0...
# 3     http://images.amazon.com/images/P/0439139597.0...
# 4     http://images.amazon.com/images/P/0439139600.0...
# ...                                                 ...
# 1127  http://images.amazon.com/images/P/0446516538.0...
# 1128  http://images.amazon.com/images/P/074932032X.0...
# 1129  http://images.amazon.com/images/P/0749317647.0...
# 1130  http://images.amazon.com/images/P/0140244824.0...
# 1131  http://images.amazon.com/images/P/0971880107.0...
#
#                                             Image-URL-L
# 0     http://images.amazon.com/images/P/0439136350.0...
# 1     http://images.amazon.com/images/P/0439136369.0...
# 2     http://images.amazon.com/images/P/0786222743.0...
# 3     http://images.amazon.com/images/P/0439139597.0...
# 4     http://images.amazon.com/images/P/0439139600.0...
# ...                                                 ...
# 1127  http://images.amazon.com/images/P/0446516538.0...
# 1128  http://images.amazon.com/images/P/074932032X.0...
# 1129  http://images.amazon.com/images/P/0749317647.0...
# 1130  http://images.amazon.com/images/P/0140244824.0...
# 1131  http://images.amazon.com/images/P/0971880107.0...
#
# [1132 rows x 10 columns]

# %%
popular_new_df[["Book-Title", "Book-Author", "Image-URL-M", "number-ratings", "average-ratings"]]
# Out:
#                                              Book-Title          Book-Author  \
# 0     Harry Potter and the Prisoner of Azkaban (Book 3)        J. K. Rowling
# 1     Harry Potter and the Prisoner of Azkaban (Book 3)        J. K. Rowling
# 2     Harry Potter and the Prisoner of Azkaban (Book 3)        J. K. Rowling
# 3          Harry Potter and the Goblet of Fire (Book 4)        J. K. Rowling
# 4          Harry Potter and the Goblet of Fire (Book 4)        J. K. Rowling
# ...                                                 ...                  ...
# 1127                           Slow Waltz in Cedar Bend  Robert James Waller
# 1128                           Slow Waltz in Cedar Bend  Robert James Waller
# 1129                           Slow Waltz in Cedar Bend  Robert James Waller
# 1130  Songs in Ordinary Time (Oprah's Book Club (Pap...  Mary McGarry Morris
# 1131                                        Wild Animus         Rich Shapero
#
#                                             Image-URL-M  number-ratings  \
# 0     http://images.amazon.com/images/P/0439136350.0...             428
# 1     http://images.amazon.com/images/P/0439136369.0...             428
# 2     http://images.amazon.com/images/P/0786222743.0...             428
# 3     http://images.amazon.com/images/P/0439139597.0...             387
# 4     http://images.amazon.com/images/P/0439139600.0...             387
# ...                                                 ...             ...
# 1127  http://images.amazon.com/images/P/0446516538.0...             248
# 1128  http://images.amazon.com/images/P/074932032X.0...             248
# 1129  http://images.amazon.com/images/P/0749317647.0...             248
# 1130  http://images.amazon.com/images/P/0140244824.0...             232
# 1131  http://images.amazon.com/images/P/0971880107.0...            2502
#
#       average-ratings
# 0            5.852804
# 1            5.852804
# 2            5.852804
# 3            5.824289
# 4            5.824289
# ...               ...
# 1127         1.895161
# 1128         1.895161
# 1129         1.895161
# 1130         1.857759
# 1131         1.019584
#
# [1132 rows x 5 columns]

# %%
popular_new_df["Image-URL-M"][0]
# Out:
# 'http://images.amazon.com/images/P/0439136350.01.MZZZZZZZ.jpg'

# %%
# now coolabrative based filtering

rating_with_name.groupby("User-ID")
rating_with_name
# Out:
#          User-ID        ISBN  Book-Rating  \
# 0         276725  034545104X            0
# 1         276726  0155061224            5
# 2         276727  0446520802            0
# 3         276729  052165615X            3
# 4         276729  0521795028            6
# ...          ...         ...          ...
# 1031131   276704  0876044011            0
# 1031132   276704  1563526298            9
# 1031133   276706  0679447156            0
# 1031134   276709  0515107662           10
# 1031135   276721  0590442449           10
#
#                                                 Book-Title        Book-Author  \
# 0                                     Flesh Tones: A Novel         M. J. Rose
# 1                                         Rites of Passage         Judith Rae
# 2                                             The Notebook    Nicholas Sparks
# 3                                           Help!: Level 1      Philip Prowse
# 4        The Amsterdam Connection : Level 4 (Cambridge ...        Sue Leather
# ...                                                    ...                ...
# 1031131  Edgar Cayce on the Akashic Records: The Book o...  Kevin J. Todeschi
# 1031132  Get Clark Smart : The Ultimate Guide for the S...       Clark Howard
# 1031133  Eight Weeks to Optimum Health: A Proven Progra...        Andrew Weil
# 1031134   The Sherbrooke Bride (Bride Trilogy (Paperback))  Catherine Coulter
# 1031135                                  Fourth Grade Rats     Jerry Spinelli
#
#         Year-Of-Publication  \
# 0                      2002
# 1                      2001
# 2                      1996
# 3                      1999
# 4                      2001
# ...                     ...
# 1031131                1998
# 1031132                2000
# 1031133                1997
# 1031134                1996
# 1031135                1996
#
#                                                  Publisher  \
# 0                                         Ballantine Books
# 1                                                   Heinle
# 2                                             Warner Books
# 3                               Cambridge University Press
# 4                               Cambridge University Press
# ...                                                    ...
# 1031131  A.R.E. Press (Association of Research &amp; Enlig
# 1031132                                   Longstreet Press
# 1031133                                    Alfred A. Knopf
# 1031134                                         Jove Books
# 1031135                                         Scholastic
#
#                                                Image-URL-S  \
# 0        http://images.amazon.com/images/P/034545104X.0...
# 1        http://images.amazon.com/images/P/0155061224.0...
# 2        http://images.amazon.com/images/P/0446520802.0...
# 3        http://images.amazon.com/images/P/052165615X.0...
# 4        http://images.amazon.com/images/P/0521795028.0...
# ...                                                    ...
# 1031131  http://images.amazon.com/images/P/0876044011.0...
# 1031132  http://images.amazon.com/images/P/1563526298.0...
# 1031133  http://images.amazon.com/images/P/0679447156.0...
# 1031134  http://images.amazon.com/images/P/0515107662.0...
# 1031135  http://images.amazon.com/images/P/0590442449.0...
#
#                                                Image-URL-M  \
# 0        http://images.amazon.com/images/P/034545104X.0...
# 1        http://images.amazon.com/images/P/0155061224.0...
# 2        http://images.amazon.com/images/P/0446520802.0...
# 3        http://images.amazon.com/images/P/052165615X.0...
# 4        http://images.amazon.com/images/P/0521795028.0...
# ...                                                    ...
# 1031131  http://images.amazon.com/images/P/0876044011.0...
# 1031132  http://images.amazon.com/images/P/1563526298.0...
# 1031133  http://images.amazon.com/images/P/0679447156.0...
# 1031134  http://images.amazon.com/images/P/0515107662.0...
# 1031135  http://images.amazon.com/images/P/0590442449.0...
#
#                                                Image-URL-L
# 0        http://images.amazon.com/images/P/034545104X.0...
# 1        http://images.amazon.com/images/P/0155061224.0...
# 2        http://images.amazon.com/images/P/0446520802.0...
# 3        http://images.amazon.com/images/P/052165615X.0...
# 4        http://images.amazon.com/images/P/0521795028.0...
# ...                                                    ...
# 1031131  http://images.amazon.com/images/P/0876044011.0...
# 1031132  http://images.amazon.com/images/P/1563526298.0...
# 1031133  http://images.amazon.com/images/P/0679447156.0...
# 1031134  http://images.amazon.com/images/P/0515107662.0...
# 1031135  http://images.amazon.com/images/P/0590442449.0...
#
# [1031136 rows x 10 columns]

# %%
x=rating_with_name.groupby("User-ID").count()["Book-Rating"]>=50

# %%
# User based filtering

Literate_user=x[x].index
Literate_user
# Out:
# Index([   243,    254,    507,    638,    643,    741,    882,    929,   1025,
#          1211,
#        ...
#        277928, 277965, 278026, 278137, 278144, 278188, 278418, 278582, 278633,
#        278843],
#       dtype='int64', name='User-ID', length=3058)

# %%
filter_rating=rating_with_name[rating_with_name['User-ID'].isin(Literate_user)]

# %%
# Book based rating

y=filter_rating.groupby("Book-Title").count()["Book-Rating"]>=50

famous_books=y[y]
famous_books.shape
# Out:
# (1360,)

# %%
final_rating=filter_rating[filter_rating['Book-Title'].isin(famous_books.index)]
final_rating
# Out:
#          User-ID        ISBN  Book-Rating  \
# 298       276925  002542730X           10
# 303       276925  0140327592            0
# 310       276925  0316666343            0
# 313       276925  0385504209            8
# 335       276925  0804106304            0
# ...          ...         ...          ...
# 1031073   276688  0553575104            6
# 1031080   276688  0679419810            0
# 1031084   276688  0679751521            0
# 1031089   276688  068484267X            0
# 1031100   276688  0788192043            0
#
#                                                 Book-Title        Book-Author  \
# 298      Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner
# 303                                                Matilda         Roald Dahl
# 310                              The Lovely Bones: A Novel       Alice Sebold
# 313                                      The Da Vinci Code          Dan Brown
# 335                                      The Joy Luck Club            Amy Tan
# ...                                                    ...                ...
# 1031073                    In Pursuit of the Proper Sinner   Elizabeth George
# 1031080                                        Strip Tease       Carl Hiaasen
# 1031084            Midnight in the Garden of Good and Evil       John Berendt
# 1031089                           Angela's Ashes: A Memoir      Frank McCourt
# 1031100                          The Hundred Secret Senses            Amy Tan
#
#         Year-Of-Publication                  Publisher  \
# 298                    1994  John Wiley &amp; Sons Inc
# 303                    1990         Viking Penguin Inc
# 310                    2002              Little, Brown
# 313                    2003                  Doubleday
# 335                    1994       Prentice Hall (K-12)
# ...                     ...                        ...
# 1031073                2000               Bantam Books
# 1031080                1993           Random House Inc
# 1031084                1999          Vintage Books USA
# 1031089                1999                   Scribner
# 1031100                2000   DIANE Publishing Company
#
#                                                Image-URL-S  \
# 298      http://images.amazon.com/images/P/002542730X.0...
# 303      http://images.amazon.com/images/P/0140327592.0...
# 310      http://images.amazon.com/images/P/0316666343.0...
# 313      http://images.amazon.com/images/P/0385504209.0...
# 335      http://images.amazon.com/images/P/0804106304.0...
# ...                                                    ...
# 1031073  http://images.amazon.com/images/P/0553575104.0...
# 1031080  http://images.amazon.com/images/P/0679419810.0...
# 1031084  http://images.amazon.com/images/P/0679751521.0...
# 1031089  http://images.amazon.com/images/P/068484267X.0...
# 1031100  http://images.amazon.com/images/P/0788192043.0...
#
#                                                Image-URL-M  \
# 298      http://images.amazon.com/images/P/002542730X.0...
# 303      http://images.amazon.com/images/P/0140327592.0...
# 310      http://images.amazon.com/images/P/0316666343.0...
# 313      http://images.amazon.com/images/P/0385504209.0...
# 335      http://images.amazon.com/images/P/0804106304.0...
# ...                                                    ...
# 1031073  http://images.amazon.com/images/P/0553575104.0...
# 1031080  http://images.amazon.com/images/P/0679419810.0...
# 1031084  http://images.amazon.com/images/P/0679751521.0...
# 1031089  http://images.amazon.com/images/P/068484267X.0...
# 1031100  http://images.amazon.com/images/P/0788192043.0...
#
#                                                Image-URL-L
# 298      http://images.amazon.com/images/P/002542730X.0...
# 303      http://images.amazon.com/images/P/0140327592.0...
# 310      http://images.amazon.com/images/P/0316666343.0...
# 313      http://images.amazon.com/images/P/0385504209.0...
# 335      http://images.amazon.com/images/P/0804106304.0...
# ...                                                    ...
# 1031073  http://images.amazon.com/images/P/0553575104.0...
# 1031080  http://images.amazon.com/images/P/0679419810.0...
# 1031084  http://images.amazon.com/images/P/0679751521.0...
# 1031089  http://images.amazon.com/images/P/068484267X.0...
# 1031100  http://images.amazon.com/images/P/0788192043.0...
#
# [132711 rows x 10 columns]

# %%
final_rating.drop_duplicates()
# Out:
#          User-ID        ISBN  Book-Rating  \
# 298       276925  002542730X           10
# 303       276925  0140327592            0
# 310       276925  0316666343            0
# 313       276925  0385504209            8
# 335       276925  0804106304            0
# ...          ...         ...          ...
# 1031073   276688  0553575104            6
# 1031080   276688  0679419810            0
# 1031084   276688  0679751521            0
# 1031089   276688  068484267X            0
# 1031100   276688  0788192043            0
#
#                                                 Book-Title        Book-Author  \
# 298      Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner
# 303                                                Matilda         Roald Dahl
# 310                              The Lovely Bones: A Novel       Alice Sebold
# 313                                      The Da Vinci Code          Dan Brown
# 335                                      The Joy Luck Club            Amy Tan
# ...                                                    ...                ...
# 1031073                    In Pursuit of the Proper Sinner   Elizabeth George
# 1031080                                        Strip Tease       Carl Hiaasen
# 1031084            Midnight in the Garden of Good and Evil       John Berendt
# 1031089                           Angela's Ashes: A Memoir      Frank McCourt
# 1031100                          The Hundred Secret Senses            Amy Tan
#
#         Year-Of-Publication                  Publisher  \
# 298                    1994  John Wiley &amp; Sons Inc
# 303                    1990         Viking Penguin Inc
# 310                    2002              Little, Brown
# 313                    2003                  Doubleday
# 335                    1994       Prentice Hall (K-12)
# ...                     ...                        ...
# 1031073                2000               Bantam Books
# 1031080                1993           Random House Inc
# 1031084                1999          Vintage Books USA
# 1031089                1999                   Scribner
# 1031100                2000   DIANE Publishing Company
#
#                                                Image-URL-S  \
# 298      http://images.amazon.com/images/P/002542730X.0...
# 303      http://images.amazon.com/images/P/0140327592.0...
# 310      http://images.amazon.com/images/P/0316666343.0...
# 313      http://images.amazon.com/images/P/0385504209.0...
# 335      http://images.amazon.com/images/P/0804106304.0...
# ...                                                    ...
# 1031073  http://images.amazon.com/images/P/0553575104.0...
# 1031080  http://images.amazon.com/images/P/0679419810.0...
# 1031084  http://images.amazon.com/images/P/0679751521.0...
# 1031089  http://images.amazon.com/images/P/068484267X.0...
# 1031100  http://images.amazon.com/images/P/0788192043.0...
#
#                                                Image-URL-M  \
# 298      http://images.amazon.com/images/P/002542730X.0...
# 303      http://images.amazon.com/images/P/0140327592.0...
# 310      http://images.amazon.com/images/P/0316666343.0...
# 313      http://images.amazon.com/images/P/0385504209.0...
# 335      http://images.amazon.com/images/P/0804106304.0...
# ...                                                    ...
# 1031073  http://images.amazon.com/images/P/0553575104.0...
# 1031080  http://images.amazon.com/images/P/0679419810.0...
# 1031084  http://images.amazon.com/images/P/0679751521.0...
# 1031089  http://images.amazon.com/images/P/068484267X.0...
# 1031100  http://images.amazon.com/images/P/0788192043.0...
#
#                                                Image-URL-L
# 298      http://images.amazon.com/images/P/002542730X.0...
# 303      http://images.amazon.com/images/P/0140327592.0...
# 310      http://images.amazon.com/images/P/0316666343.0...
# 313      http://images.amazon.com/images/P/0385504209.0...
# 335      http://images.amazon.com/images/P/0804106304.0...
# ...                                                    ...
# 1031073  http://images.amazon.com/images/P/0553575104.0...
# 1031080  http://images.amazon.com/images/P/0679419810.0...
# 1031084  http://images.amazon.com/images/P/0679751521.0...
# 1031089  http://images.amazon.com/images/P/068484267X.0...
# 1031100  http://images.amazon.com/images/P/0788192043.0...
#
# [132711 rows x 10 columns]

# %%
pt=final_rating.pivot_table(index="Book-Title",columns="User-ID",values="Book-Rating")
print("Pivot Table:")
pt
# Out:
# Pivot Table:
# User-ID                                             243     254     507     \
# Book-Title
# 1984                                                   NaN     9.0     NaN
# 1st to Die: A Novel                                    NaN     NaN     0.0
# 2010: Odyssey Two                                      NaN     NaN     NaN
# 204 Rosewood Lane                                      NaN     NaN     NaN
# 24 Hours                                               NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Year of Wonders                                        NaN     NaN     NaN
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# User-ID                                             638     643     741     \
# Book-Title
# 1984                                                   NaN     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2010: Odyssey Two                                      NaN     NaN     NaN
# 204 Rosewood Lane                                      NaN     NaN     NaN
# 24 Hours                                               NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Year of Wonders                                        NaN     NaN     NaN
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# User-ID                                             882     929     1025    \
# Book-Title
# 1984                                                   NaN     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2010: Odyssey Two                                      NaN     NaN     NaN
# 204 Rosewood Lane                                      NaN     NaN     NaN
# 24 Hours                                               NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Year of Wonders                                        NaN     NaN     NaN
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# User-ID                                             1211    ...  277928  \
# Book-Title                                                  ...
# 1984                                                   NaN  ...     NaN
# 1st to Die: A Novel                                    NaN  ...     NaN
# 2010: Odyssey Two                                      NaN  ...     NaN
# 204 Rosewood Lane                                      NaN  ...     NaN
# 24 Hours                                               NaN  ...     NaN
# ...                                                    ...  ...     ...
# Year of Wonders                                        NaN  ...     NaN
# You Belong To Me                                       NaN  ...     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN  ...     NaN
# Zoya                                                   NaN  ...     NaN
# \O\" Is for Outlaw"                                    NaN  ...     NaN
#
# User-ID                                             277965  278026  278137  \
# Book-Title
# 1984                                                   NaN     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2010: Odyssey Two                                      NaN     NaN     NaN
# 204 Rosewood Lane                                      NaN     NaN     NaN
# 24 Hours                                               NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Year of Wonders                                        NaN     NaN     NaN
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# User-ID                                             278144  278188  278418  \
# Book-Title
# 1984                                                   NaN     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2010: Odyssey Two                                      NaN     NaN     NaN
# 204 Rosewood Lane                                      NaN     0.0     NaN
# 24 Hours                                               NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Year of Wonders                                        NaN     NaN     NaN
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# User-ID                                             278582  278633  278843
# Book-Title
# 1984                                                   NaN     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2010: Odyssey Two                                      NaN     NaN     NaN
# 204 Rosewood Lane                                      NaN     NaN     NaN
# 24 Hours                                               NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Year of Wonders                                        NaN     NaN     NaN
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# [1360 rows x 2992 columns]

# %%
pt.fillna(0,inplace=True)
pt
# Out:
# User-ID                                             243     254     507     \
# Book-Title
# 1984                                                   0.0     9.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2010: Odyssey Two                                      0.0     0.0     0.0
# 204 Rosewood Lane                                      0.0     0.0     0.0
# 24 Hours                                               0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# User-ID                                             638     643     741     \
# Book-Title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2010: Odyssey Two                                      0.0     0.0     0.0
# 204 Rosewood Lane                                      0.0     0.0     0.0
# 24 Hours                                               0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# User-ID                                             882     929     1025    \
# Book-Title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2010: Odyssey Two                                      0.0     0.0     0.0
# 204 Rosewood Lane                                      0.0     0.0     0.0
# 24 Hours                                               0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# User-ID                                             1211    ...  277928  \
# Book-Title                                                  ...
# 1984                                                   0.0  ...     0.0
# 1st to Die: A Novel                                    0.0  ...     0.0
# 2010: Odyssey Two                                      0.0  ...     0.0
# 204 Rosewood Lane                                      0.0  ...     0.0
# 24 Hours                                               0.0  ...     0.0
# ...                                                    ...  ...     ...
# Year of Wonders                                        0.0  ...     0.0
# You Belong To Me                                       0.0  ...     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0  ...     0.0
# Zoya                                                   0.0  ...     0.0
# \O\" Is for Outlaw"                                    0.0  ...     0.0
#
# User-ID                                             277965  278026  278137  \
# Book-Title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2010: Odyssey Two                                      0.0     0.0     0.0
# 204 Rosewood Lane                                      0.0     0.0     0.0
# 24 Hours                                               0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# User-ID                                             278144  278188  278418  \
# Book-Title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2010: Odyssey Two                                      0.0     0.0     0.0
# 204 Rosewood Lane                                      0.0     0.0     0.0
# 24 Hours                                               0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# User-ID                                             278582  278633  278843
# Book-Title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2010: Odyssey Two                                      0.0     0.0     0.0
# 204 Rosewood Lane                                      0.0     0.0     0.0
# 24 Hours                                               0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# [1360 rows x 2992 columns]

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
# similarity_score = cosine_similarity(pt).shape
similarity_score = cosine_similarity(pt)

# %%
similarity_score
# Out:
# array([[1.        , 0.04563786, 0.06307455, ..., 0.05468059, 0.03721831,
#         0.0206412 ],
#        [0.04563786, 1.        , 0.01695641, ..., 0.03826821, 0.12763956,
#         0.09407019],
#        [0.06307455, 0.01695641, 1.        , ..., 0.07303747, 0.        ,
#         0.        ],
#        ...,
#        [0.05468059, 0.03826821, 0.07303747, ..., 1.        , 0.04144573,
#         0.01083467],
#        [0.03721831, 0.12763956, 0.        , ..., 0.04144573, 1.        ,
#         0.06569498],
#        [0.0206412 , 0.09407019, 0.        , ..., 0.01083467, 0.06569498,
#         1.        ]])

# %%
np.where(pt.index=="Year of Wonders")[0][0]
# Out:
# 1355

# %%
def recommended_books(book_name):
    try:
        # Check if the specified book is in the user-item matrix
        index = np.where(pt.index == book_name)[0][0]
    except IndexError:
        print(f"The book '{book_name}' is not found in the dataset.")
        return

    print(f"Index of '{book_name}': {index}")

    # Ensure the index is within the valid range of the similarity_score tuple
    if index >= len(similarity_score):
        print(f"Error: Index {index} is out of range for similarity_score.")
        return

    # Getting the similarity scores for the specified book
    book_similarity = similarity_score[index]


    # Sorting the enumerated list of similar items based on similarity scores
    similar_items = sorted(enumerate(book_similarity), key=lambda x: x[1], reverse=True)

    # Extracting the top 5 recommended books
    top_recommendations = [pt.index[i[0]] for i in similar_items[1:6]]  # Exclude the input book itself

    # Printing recommended books
    print("Top 5 recommended books for", book_name, "are:")
    for book in top_recommendations:
        print(book)

recommended_books("The Notebook")
# Out:
# Index of 'The Notebook': 1122
# Top 5 recommended books for The Notebook are:
# The Rescue
# A Walk to Remember
# Message in a Bottle
# Nights in Rodanthe
# Suzanne's Diary for Nicholas

# %%
with open('recomender.pkl', 'wb') as file:
    pickle.dump((pt, similarity_score, popular_new_df), file)
